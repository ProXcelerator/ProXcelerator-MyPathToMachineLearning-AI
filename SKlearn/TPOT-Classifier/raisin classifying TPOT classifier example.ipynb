# %%
# !pip install install tpot
# Out:
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting tpot
#   Downloading TPOT-0.12.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 87.4/87.4 kB 1.6 MB/s eta 0:00:00
# Collecting deap>=1.2
#   Downloading deap-1.3.3-cp310-cp310-win_amd64.whl (114 kB)
#      -------------------------------------- 114.3/114.3 kB 6.5 MB/s eta 0:00:00
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.7.6-py3-none-win_amd64.whl (70.9 MB)
#      --------------------------------------- 70.9/70.9 MB 10.6 MB/s eta 0:00:00
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=0.24.2 in c:\users\taylor\anaconda3\lib\site-packages (from tpot) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\taylor\anaconda3\lib\site-packages (from tpot) (1.2.1)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\taylor\anaconda3\lib\site-packages (from tpot) (1.10.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\taylor\anaconda3\lib\site-packages (from tpot) (1.23.5)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\taylor\anaconda3\lib\site-packages (from tpot) (1.1.1)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\taylor\anaconda3\lib\site-packages (from tpot) (4.64.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\taylor\anaconda3\lib\site-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\taylor\anaconda3\lib\site-packages (from pandas>=0.24.2->tpot) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\taylor\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->tpot) (2.2.0)
# Requirement already satisfied: colorama in c:\users\taylor\anaconda3\lib\site-packages (from tqdm>=4.36.1->tpot) (0.4.6)
# Requirement already satisfied: requests>=2.3.0 in c:\users\taylor\anaconda3\lib\site-packages (from update-checker>=0.16->tpot) (2.28.1)
# Requirement already satisfied: six>=1.5 in c:\users\taylor\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\taylor\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\taylor\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\taylor\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\taylor\anaconda3\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2022.12.7)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py): started
#   Building wheel for stopit (setup.py): finished with status 'done'
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=12019 sha256=766987ca21056787c33d8d34888d8295c5ded046de04c6919d8e0d2052f6acfc
#   Stored in directory: c:\users\taylor\appdata\local\pip\cache\wheels\ac\b6\fc\67f7dd6291ee9a509bb12bb9b80773eed4b88bd55292ac672f
# Successfully built stopit
# Installing collected packages: stopit, install, deap, xgboost, update-checker, tpot
# Successfully installed deap-1.3.3 install-1.3.5 stopit-1.1.2 tpot-0.12.0 update-checker-0.18.0 xgboost-1.7.6

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from skopt import BayesSearchCV
from skopt.space import Categorical, Real
from tpot import TPOTClassifier

# Load the data set
raisins = pd.read_csv('raisin-classifier.csv')
X = raisins.drop('Class', axis=1)
y = raisins['Class']
# print(raisins)
# Split the data set into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2)

# Create an SVC model
# svm = SVC()

# Dictionary of parameters for GridSearchCV
# parameters = {'kernel': ['rbf', 'linear', 'sigmoid'], 'C': [1, 10, 100]}

# # Create a GridSearchCV model
# grid = GridSearchCV(svm, parameters)

# # Fit the GridSearchCV model to the training data
# grid.fit(X_train, y_train)

# # Print the model and hyperparameters obtained by GridSearchCV
# print(grid.best_estimator_)

# # # Print a table summarizing the results of GridSearchCV
# df = pd.concat([pd.DataFrame(grid.cv_results_['params']), pd.DataFrame(grid.cv_results_['mean_test_score'], columns=['Score'])], axis=1)
 
# cv_table = df.pivot(index='kernel', columns='C')
 
# print(cv_table)
# Print the accuracy of the final model on the test data
# acc = grid.score(X_test, y_test)
# print(acc)

# Dictionary of parameters for BayesSearchCV
# search_spaces = {'kernel': Categorical(['rbf']), 'C': Real(1, 10, prior='uniform')}

# # Create a BayesSearchCV model
# bayes = BayesSearchCV(svm, search_spaces, n_iter = 10)

# # Fit the BayesSearchCV model to the training data
# bayes.fit(X_train, y_train)

# # Print the model and hyperparameters obtained by BayesSearchCV
# print(bayes.best_estimator_)

# # Print the accuracy of the final model on the test data
# print(bayes.score(X_test, y_test))
# OUTPUT:
# SVC(C=9.981011926730542)
# 0.7944444444444444


# Create a TPOTClassifier model
tpot = TPOTClassifier(generations = 2, population_size = 20)

# Fit the TPOTClassifier model to the training data
tpot.fit(X_train, y_train)

# Print the accuracy of the final model on the test data
print(tpot.score(X_test, y_test))

# Export TPOTClassifier's final model to a separate file
# tpot.export('tpot_pipline.py')
# Out:
# 0.8611111111111112
